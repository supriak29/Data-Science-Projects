# %% [markdown]
# <html>
# <body>
# <ol>
#     <li>
#         Entry_id
#         <ul>
#             <li>User identifier </li>
#             <li>This in this case is a random number for every single person</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         age
#         <ul>
#             <li>Applicants have to be 18 or older to qualify</li>
#             <li>Age group: (18-100)</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         pay_schedule
#         <ul>
#             <li>pay schedule is an indicator of how often the applicant gets paid weekly</li>
#             <li>weekly: once a week</li>
#             <li>bi-weekly: every 2 weeks</li>
#             <li>semi-monthly: twice a month</li>
#             <li>monthly: once a month</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         home_owner
#             <ul>
#             <li>two levels: 0 and 1</li>
#             <li>1: user is the owner of the house</li>
#             <li>0: user is not the owner of the house; renting the house or some other accommodation</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         income
#             <ul>
#             <li>monthly income of the applicant</li>
#             <li>the sum of all the paychecks they got in that particular month</li>
#             <li>this is an estimate that comes from the P2P marketplace as well</li>
#             <li>Or this could be also a calculation based on the features that the user gave us at the beginning of the application process again in the marketplace.</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         years_employed
#             <ul>
#             <li>number indicating how many years the person has worked in their current job</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         current_address_year
#             <ul>
#             <li>how many years the person has stayed in their current address</li>
#             <li>So have they been living in that house or an apartment for a long period of time or not?</li>
#         </ul>
#     </li>
#     <br>
#     <li>personal_account_m</li>
#     <li>personal_account_y
#             <ul>
#             <li>how many months that person has had their personal account on</li>
#             <li>these two columns right here are a combination</li>
#             <li>the first user in this data set, has had their account for two years and six months</li>
#             <li>These two columns are about their latest credit account, credit card, things like that</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         has_debt
#             <ul>
#             <li>if a person has a debt</li>
#             <li>whether or not the person has had any debt or any positive balance</li>
#             <li>meaning that they owe money in their credit account or whether or not they are clean</li>
#             <li>So this relates to these two columns in the past: (personal_account_m, personal_account_y)</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         amount_requested
#             <ul>
#             <li>what the user decided to apply for the loan applicant</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         risk_score
#             <ul>
#             <li>beginning of the set of five scores that are given to us by our finance and engineering teams</li>
#             <li>evaluates whether or not the user is likely to pay the loan, is likely to sign the loan and things of the sort</li>
#             <li>So these risk scores are not built to predict the onboarding process</li>
#             <li>They are built to predict whether or not the user is going to fulfill the actual application to receive the loan, accept the loan and whether or not they're going to pay the loan.</li>
#                 <br>
#             <li>Although it is not exactly related about our response variable, this is something that we can still leverage because there still has to be some kind of relationship between these risk scores and the likelihood of reaching that E sign in screen.</li>
#         </ul>
#         <br>
#     </li>
#     <li>risk_score_2</li>
#     <li>risk_score_3</li>
#     <li>risk_score_4</li>
#     <li>risk_score_5
#             <ul>
#             <li>So this is a very different risk scores, meaning that they are based on different factors</li>
#             <li>ranges from 0-1</li>
#         </ul>
#     </li>
#     <br>
#     <li>ext_quality_sore</li>
#     <li>ext_quality_sore_2
#             <ul>
#             <li>external quality score</li>
#             <li>values from 0-1</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         inquiries_last_month
#             <ul>
#             <li>So how many inquiries the user has had in the last month?</li>
#             <li>And this is just a number based on how many times the user has had a heart check on their credit score, also known as a hard pull</li>
#         </ul>
#     </li>
#     <br>
#     <li>
#         e_signed
#             <ul>
#             <li>response variable</li>
#             <li>1: person has completed the signing process</li>
#             <li>0: zero means that the person has not completed the E signing process</li>
#         </ul>
#     </li>
# </ol>
# </body>
# </html>
